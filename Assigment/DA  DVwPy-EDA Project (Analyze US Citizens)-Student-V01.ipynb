# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df=pd.read_csv("adult_eda.csv")

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
# Check if the Dataset have any Duplicate
df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
# Drop Duplicates
df2=df.drop_duplicates()

# %%
# Check the shape of the Dataset
df2.shape
# Out:
# (32537, 15)

# %%
df2.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %% [markdown]
# **Rename the features of;**<br>
# **``"education-num"``**, **``"marital-status"``**, **``"capital-gain"``**, **``"capital-loss"``**, **``"hours-per-week"``**, **``"native-country"``** **as**<br>
# **``"education_num"``**, **``"marital_status"``**, **``"capital_gain"``**, **``"capital_loss"``**, **``"hours_per_week"``**, **``"native_country"``**, **respectively and permanently.**

# %%
df2.columns=df2.columns.str.replace("-","_")

# %%
df2.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# Check the sum of Missing Values per column
df2.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values
100*df2.isnull().sum()/len(df)
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.463
# marital_status    0.000
# occupation        0.000
# relationship     15.552
# race              0.000
# sex               0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
df2.T.index
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
df2.describe(include="object").T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %% [markdown]
# **Assign the Columns (Features) of object data type as** **``"object_col"``**

# %%
object_col=df2.select_dtypes(include="object").columns

# %%
object_col
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(df2[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# ...

# %% [markdown]
# **Check if the Dataset has any Question Mark** **``"?"``**

# %%
(df2=="?").any(axis=0)

#df.applymap(lambda x: True if x == "?" else False).any(axis = 0)
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## Salary (Target Feature)

# %% [markdown]
# **Check the count of person in each "salary" levels and visualize it with a countplot**

# %%
df2.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
group_salary=df2.salary.value_counts()
group_salary
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
plt.figure(figsize=(12,8))
bar1=plt.bar(x=group_salary.index,height=group_salary,color=["#0d2752","#0ff539"])
plt.xlabel("Salary")
plt.ylabel("Count")
plt.bar_label(bar1)
plt.show()

# %% [markdown]
# **Check the percentage of person in each "salary" levels and visualize it with a pieplot**

# %%
perc_sal=group_salary/len(df.salary)
perc_sal
# Out:
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(12,8))
plt.pie(perc_sal,labels=perc_sal.index,autopct="%.2f%%",textprops={"fontsize":15},explode=[0,.1],shadow=True,colors=["#f22cb0","#9bebcd"])
plt.title("Percentage of income-Levels",fontdict={"fontsize":18})
plt.show()

# %% [markdown]
# **Result :** Approximately 76% of them have a salary below 50K

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ## age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
plt.figure(figsize=(15,8))
sns.boxplot(df2.age,color="#98ed37")
plt.show()

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
plt.figure(figsize=(12,8))
sns.histplot(df2.age,kde=True,bins=20,color="#26eb4d");

# %% [markdown]
# **Check the statistical values**

# %%
df2.age.describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
plt.figure(figsize=(12,8))
sns.boxplot(df2.salary,df2.age,palette="BuGn");

# %%
plt.figure(figsize=(12,8))
sns.histplot(x=df2.age,hue=df2.salary,bins=20,kde=True,palette="twilight_r");

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(x=df2.age,hue=df2.salary,shade=True,palette="winter_r");

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df2.groupby("salary").describe().age
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ................

# %% [markdown]
# ## fnlwgt

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
plt.figure(figsize=(12,8))
sns.boxplot(df2.fnlwgt,color="#c0eb26");

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(df2.fnlwgt,shade=True,color="#f21b1b");

# %% [markdown]
# **Check the statistical values**

# %%
df2.fnlwgt.describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x=df2.salary,y=df2.fnlwgt,palette="cubehelix");

# %%
plt.figure(figsize=(12,10))
sns.kdeplot(x=df2.fnlwgt,hue=df2.salary,shade=True,palette="cubehelix");

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df2.groupby("salary").describe().fnlwgt
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** ...............

# %% [markdown]
# ## capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=df2.capital_gain);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(x=df2.capital_gain,shade=True,color="#fa028b");

# %% [markdown]
# **Check the statistical values**

# %%
df2.capital_gain.describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df2.salary,y=df2.capital_gain);

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(x=df2.capital_gain,hue=df2.salary,shade=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df2.groupby("salary").describe().capital_gain
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %%
df2[df2["capital_gain"] != 0].groupby("salary").describe().capital_gain
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** For those whose salary is less than 50 ; it is a density of capital gain which have between 0 to 40000 capital gain especially at 0

# %% [markdown]
# ## capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
plt.figure(figsize=(9,5))
sns.boxplot(df2.capital_loss);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(x=df2.capital_loss,shade=True,color="purple");

# %% [markdown]
# **Check the statistical values**

# %%
df2.capital_loss.describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df2.salary,y=df2.capital_loss);

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(x=df2.capital_loss,hue=df2.salary,shade=True,palette="cool_r");

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df2.groupby("salary").describe().capital_loss
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %%
df2[df2["capital_loss"] != 0 ].groupby("salary").describe().capital_loss
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**There is a density in the number of people with no capital loss among those whose salary is below or above 50 k.Percentage of number of high level income group more than low level income group.

# %% [markdown]
# ## hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
plt.figure(figsize=(9,6))
sns.boxplot(x=df2.hours_per_week,color="#02fa07");

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
plt.figure(figsize=(9,6))
sns.kdeplot(x=df2.hours_per_week,shade=True,color="#fa7602");

# %% [markdown]
# **Check the statistical values**

# %%
df2.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
plt.figure(figsize=(9,5))
sns.boxplot(x=df2.salary,y=df2.hours_per_week,palette="twilight");

# %%
plt.figure(figsize=(9,6))
sns.kdeplot(x=df2.hours_per_week,hue=df2.salary,shade=True,palette="magma_r");

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
df2.groupby("salary").describe().hours_per_week
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Both of them mean of hours per week is close to each other.There seems to be some extreme values, we need to examine it in more detail to understand this

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
sns.pairplot(df2,hue="salary",corner=True,palette="autumn");

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
df2.education.value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df2.education_num.value_counts()
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
df2.groupby("education").education_num.value_counts(dropna=False)
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# ...

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df2.education,palette="spring_r")
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df2.education_num,palette="spring_r")
plt.xticks(rotation=90);

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
df2.groupby(["education"]).salary.value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df2.education,hue=df2.salary,palette="turbo")
plt.xticks(rotation=90);

# %%
df2.groupby("education_num").salary.value_counts()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df2.education_num,hue=df2.salary,palette="rocket")
plt.xticks(rotation=90);

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x=df2.salary,y=df2.education_num,palette="husl");

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
df2.education.apply(mapping_education).value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
df2["education_summary"]=df2.education.apply(mapping_education)

# %%
df2.sample(5)
# Out:
#        age    workclass  fnlwgt     education  education_num  \
# 26556   38      Private  234298     Bachelors         13.000
# 31507   38      Private  187748     Bachelors         13.000
# 26166   57  Federal-gov  313929  Some-college         10.000
# 30690   39      Private   91367       Masters            NaN
# 28402   53  Federal-gov  181677  Some-college         10.000
#
#            marital_status         occupation   relationship  \
# 26556            Divorced    Exec-managerial  Not-in-family
# 31507  Married-civ-spouse     Prof-specialty        Husband
# 26166  Married-civ-spouse     Prof-specialty        Husband
# 30690  Married-civ-spouse    Exec-managerial        Husband
# 28402            Divorced  Handlers-cleaners  Not-in-family
#
#                      race   sex  capital_gain  capital_loss  hours_per_week  \
# 26556               White  Male          6849             0              60
# 31507               White  Male             0             0              40
# ...

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %%
plt.figure(figsize=((9,6)))
sns.countplot(x=df2.education_summary,palette="cividis");

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %%
df2.groupby("education_summary").salary.value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
plt.figure(figsize=(9,6))
sns.countplot(x=df2.education_summary,hue=df2.salary,palette="autumn");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %%
a=df2.groupby("education_summary").salary.value_counts(normalize=True)
a
# Out:
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
df_a=a.unstack(level=0)
df_a
# Out:
# education_summary  high_level_grade  low_level_grade  medium_level_grade
# salary
# <=50K                         0.515            0.943               0.818
# >50K                          0.485            0.057               0.182

# %%
df_a.plot(kind="pie", subplots=True, layout=(1,3), title=["high_level_grade", "low_level_grade", "medium_level_grade"],
ylabel="salary", autopct="%.2f%%", legend=False, figsize=(15, 5), colors=["#84f5a2","#eaf584"]);

# %%
#2Way(manuel)
plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
plt.pie(x=a[0:2],labels=[a.index[0][1],a.index[1][1]],autopct="%.2f%%",colors=["#84f5a2","#eaf584"],textprops={"fontsize":"15"})
plt.title("high_level_grade ",fontdict={"fontsize":"18"})
plt.ylabel("salary")
plt.subplot(1,3,2)
plt.pie(x=a[2:4],labels=[a.index[2][1],a.index[3][1]],autopct="%.2f%%",colors=["#84f5a2","#eaf584"],textprops={"fontsize":"15"})
plt.title("low_level_grade",fontdict={"fontsize":"18"})
plt.ylabel("salary")
plt.subplot(1,3,3)
plt.pie(x=a[4:6],labels=[a.index[4][1],a.index[5][1]],autopct="%.2f%%",colors=["#84f5a2","#eaf584"],textprops={"fontsize":"15"})
plt.title("medium_level_grade",fontdict={"fontsize":"18"})
plt.ylabel("salary");

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %%
df2.groupby("salary").education_summary.value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
plt.figure(figsize=(9,6))
sns.countplot(x=df2.salary,hue=df2.education_summary,palette="twilight");

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %%
b=df2.groupby("salary").education_summary.value_counts(normalize=True)
b
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
b.unstack()
# Out:
# education_summary  high_level_grade  low_level_grade  medium_level_grade
# salary
# <=50K                         0.168            0.162               0.670
# >50K                          0.499            0.031               0.470

# %%
df_b=b.unstack(level=0)
df_b
# Out:
# salary              <=50K  >50K
# education_summary
# high_level_grade    0.168 0.499
# low_level_grade     0.162 0.031
# medium_level_grade  0.670 0.470

# %%
df_b.plot(kind="pie", subplots=True, layout=(1,2), title=["<=50K", ">50K"],
ylabel="education_summary", autopct="%.2f%%", legend=False, figsize=(15, 5), colors=["#bd450d","#eaf584","#fca63d"],startangle=200);

# %%
#2.Way (Manuel)
plt.figure(figsize=(20,13))
plt.subplot(1,2,1)
plt.pie(x=b[0:3],labels=b.index[0:3],autopct="%.2f%%",textprops={"fontsize":15},colors=["#fca63d","#eaf584","#bd450d"])
plt.title("<=50K",fontdict={"fontsize":18})
plt.ylabel("education_summary")
plt.subplot(1,2,2)
plt.pie(x=b[3:6],labels=b.index[3:6],autopct="%.2f%%",textprops={"fontsize":15},colors=["#fca63d","#eaf584","#bd450d"])
plt.ylabel("education_summary")
plt.title(">50K",fontdict={"fontsize":18});

# %%
dff_b=b.to_frame()

# %%
dff_b.columns=["percentages"]

# %%
dff_b.reset_index(inplace=True)
dff_b
# Out:
#   salary   education_summary  percentages
# 0  <=50K  medium_level_grade        0.670
# 1  <=50K    high_level_grade        0.168
# 2  <=50K     low_level_grade        0.162
# 3   >50K    high_level_grade        0.499
# 4   >50K  medium_level_grade        0.470
# 5   >50K     low_level_grade        0.031

# %%
df_b.plot(kind="pie",subplots=True,layout=(1,2),title=["<=50K", ">50K"],ylabel="percentages",autopct="%.2f%%",labels=["high","low","medium"], legend=False, figsize=(15, 5), colors=["#f578b2","#ebfc4e","#a6b3f7"]);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Those who earn more than 50k salary have higher education levels. very few of them have low education level.The general education level of people with a salary below 50 is medium level grade.

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
df2.marital_status.value_counts()
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
df2.relationship.value_counts()
# Out:
# Husband           13187
# Not-in-family      8292
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
new_r=df2.relationship.fillna("Unknown")

# %%
df2.groupby(new_r).marital_status.value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
# ...

# %% [markdown]
# **Assessment :** ........

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
plt.figure(figsize=(12,9))
sns.countplot(x=df2.marital_status,palette="husl")
plt.xticks(rotation=45);

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
df2.groupby("marital_status").salary.value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.countplot(df2.marital_status,hue=df2.salary,palette="viridis")
plt.xticks(rotation=45);

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
new_marial_status=df2.marital_status.apply(mapping_marital_status)

# %%
new_marial_status.value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
df2["marital_status_summary"]=df2.marital_status.apply(mapping_marital_status)

# %%
df2.sample(3)
# Out:
#        age  workclass  fnlwgt   education  education_num      marital_status  \
# 29398   42    Private  344572     HS-grad          9.000            Divorced
# 19457   53    Private  217568     HS-grad          9.000             Widowed
# 24141   41  State-gov  222434  Assoc-acdm         12.000  Married-civ-spouse
#
#             occupation   relationship   race     sex  capital_gain  \
# 29398  Exec-managerial  Not-in-family  White  Female             0
# 19457     Craft-repair      Unmarried  Black  Female             0
# 24141  Protective-serv        Husband  White    Male             0
#
#        capital_loss  hours_per_week native_country salary   education_summary  \
# 29398             0              40  United-States   >50K  medium_level_grade
# 19457             0              40  United-States  <=50K  medium_level_grade
# 24141             0              40  United-States  <=50K  medium_level_grade
#
#       marital_status_summary
# 29398              unmarried
# ...

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %%
plt.figure(figsize=(10,6))
sns.countplot(df2.marital_status_summary,palette="spring_r");

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %%
df2.groupby("marital_status_summary").salary.value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(df2.marital_status_summary,hue=df2.salary,palette="terrain");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %%
c=df2.groupby("marital_status_summary").salary.value_counts(normalize=True)
c
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
df_c=c.unstack(level=0)
df_c
# Out:
# marital_status_summary  married  unmarried
# salary
# <=50K                     0.563      0.935
# >50K                      0.437      0.065

# %%
df_c.plot(kind="pie",subplots=True,layout=(1,2),title=["married","unmarried"], ylabel="salary", autopct="%.2f%%",figsize=(15,9),legend=False,colors=["#a6b3f7","pink"]);

# %%
plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.pie(x=c[0:2],labels=[c.index[0][1],c.index[1][1]],autopct="%.2f%%",colors=["#a6b3f7","pink"],textprops={"fontsize":13})
plt.title("married",fontdict={"fontsize":18})
plt.ylabel("salary")
plt.subplot(1,2,2)
plt.pie(x=c[2:4],labels=[c.index[2][1],c.index[3][1]],autopct="%.2f%%",colors=["#a6b3f7","pink"],textprops={"fontsize":13})
plt.title("unmarried",fontdict={"fontsize":18})
plt.ylabel("salary");

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %%
df2.groupby("salary").marital_status_summary.value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(df2.salary,hue=df2.marital_status_summary,palette="husl");

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %%
d=df2.groupby("salary").marital_status_summary.value_counts(normalize=True)
d
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
dff_d=d.to_frame()
dff_d
# Out:
#                                marital_status_summary
# salary marital_status_summary
# <=50K  unmarried                                0.649
#        married                                  0.351
# >50K   married                                  0.859
#        unmarried                                0.141

# %%
dff_d.columns=["percentages"]

# %%
dff_d.reset_index(inplace=True)
dff_d
# Out:
#   salary marital_status_summary  percentages
# 0  <=50K              unmarried        0.649
# 1  <=50K                married        0.351
# 2   >50K                married        0.859
# 3   >50K              unmarried        0.141

# %%
df_d=d.unstack(level=0)
df_d
# Out:
# salary                  <=50K  >50K
# marital_status_summary
# married                 0.351 0.859
# unmarried               0.649 0.141

# %%
df_c.plot(kind="pie",subplots=True,layout=(1,2),title=["married","unmarried"], ylabel="salary", autopct="%.2f%%",figsize=(15,9),legend=False,colors=["#72f7a3","#dced58"]);

# %%
df_d.plot(kind="pie",subplots=True,layout=(1,2),title=["<=50",">50"],ylabel="percentage",autopct="%.2f%%",figsize=(15,9),legend=False,colors=["#72f7a3","#dced58"]);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** We can say that the marriage rate of middle- and low-income people is low. As we saw in the other case, income level affected the marriage rate.

# %% [markdown]
# ## workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df2.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(df2.workclass,palette="spring_r")
plt.xticks(rotation=90);

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
df2.workclass.replace("?","Unknown",inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
df2.groupby("workclass").salary.value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(df2.workclass,hue=df2.salary,palette="Dark2")
plt.xticks(rotation=90);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
e=df2.groupby("workclass").salary.value_counts(normalize=True)
e
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
dff_e=e.to_frame()
dff_e
# Out:
#                          salary
# workclass        salary
# Federal-gov      <=50K    0.614
#                  >50K     0.386
# Local-gov        <=50K    0.705
#                  >50K     0.295
# Never-worked     <=50K    1.000
# Private          <=50K    0.781
#                  >50K     0.219
# Self-emp-inc     >50K     0.557
#                  <=50K    0.443
# Self-emp-not-inc <=50K    0.715
#                  >50K     0.285
# State-gov        <=50K    0.728
#                  >50K     0.272
# Unknown          <=50K    0.896
#                  >50K     0.104
# Without-pay      <=50K    1.000

# %%
dff_e.columns=["percentage"]

# %%
dff_e.reset_index(inplace=True)
dff_e
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13           Unknown  <=50K       0.896
# 14           Unknown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=dff_e.workclass,y=dff_e.percentage,hue=dff_e.salary,palette="husl")
plt.xticks(rotation=90);

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
df2.groupby("salary").workclass.value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(df2.salary,hue=df2.workclass,palette="husl");

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
f=df2.groupby("salary").workclass.value_counts(normalize=True)
f
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
dff_f=f.to_frame()
dff_f
# Out:
#                          workclass
# salary workclass
# <=50K  Private               0.717
#        Self-emp-not-inc      0.074
#        Unknown               0.067
#        Local-gov             0.060
#        State-gov             0.038
#        Federal-gov           0.024
#        Self-emp-inc          0.020
#        Without-pay           0.001
#        Never-worked          0.000
# >50K   Private               0.633
#        Self-emp-not-inc      0.092
#        Self-emp-inc          0.079
#        Local-gov             0.079
#        Federal-gov           0.047
#        State-gov             0.045
#        Unknown               0.024

# %%
dff_f.columns=["percentage"]

# %%
dff_f
# Out:
#                          percentage
# salary workclass
# <=50K  Private                0.717
#        Self-emp-not-inc       0.074
#        Unknown                0.067
#        Local-gov              0.060
#        State-gov              0.038
#        Federal-gov            0.024
#        Self-emp-inc           0.020
#        Without-pay            0.001
#        Never-worked           0.000
# >50K   Private                0.633
#        Self-emp-not-inc       0.092
#        Self-emp-inc           0.079
#        Local-gov              0.079
#        Federal-gov            0.047
#        State-gov              0.045
#        Unknown                0.024

# %%
dff_f.reset_index(inplace=True)
dff_f
# Out:
#    salary         workclass  percentage
# 0   <=50K           Private       0.717
# 1   <=50K  Self-emp-not-inc       0.074
# 2   <=50K           Unknown       0.067
# 3   <=50K         Local-gov       0.060
# 4   <=50K         State-gov       0.038
# 5   <=50K       Federal-gov       0.024
# 6   <=50K      Self-emp-inc       0.020
# 7   <=50K       Without-pay       0.001
# 8   <=50K      Never-worked       0.000
# 9    >50K           Private       0.633
# 10   >50K  Self-emp-not-inc       0.092
# 11   >50K      Self-emp-inc       0.079
# 12   >50K         Local-gov       0.079
# 13   >50K       Federal-gov       0.047
# 14   >50K         State-gov       0.045
# 15   >50K           Unknown       0.024

# %%
plt.figure(figsize=(13,8))
ax = sns.barplot(data=dff_f, x="salary",y=dff_f.percentage, hue="workclass")
plt.legend(loc="upper right")
for i in ax.containers:
    ax.bar_label(i,fmt="%.3f")
plt.xticks(rotation=90);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** High level income people have workclass which is self-employment-inc or not-inc,local-gov,state-gov and private. Usually goverment jobs. Middle level income peaole have jobs self-employment,private,local-gov etc. Workclass determines salary level .

# %% [markdown]
# ## occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df2.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(df2.occupation)
plt.xticks(rotation=90);

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
df2.occupation.replace("?","Unknown",inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
df2.groupby("occupation").salary.value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(df2.occupation,hue=df2.salary,palette="rainbow")
plt.xticks(rotation=90);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %%
g=df2.groupby("occupation").salary.value_counts(normalize=True)
g
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
# ...

# %%
dff_g=g.to_frame()
dff_g
# Out:
#                           salary
# occupation        salary
# Adm-clerical      <=50K    0.865
#                   >50K     0.135
# Armed-Forces      <=50K    0.889
#                   >50K     0.111
# Craft-repair      <=50K    0.773
#                   >50K     0.227
# Exec-managerial   <=50K    0.516
#                   >50K     0.484
# Farming-fishing   <=50K    0.884
#                   >50K     0.116
# Handlers-cleaners <=50K    0.937
#                   >50K     0.063
# Machine-op-inspct <=50K    0.875
#                   >50K     0.124
# Other-service     <=50K    0.958
#                   >50K     0.042
# Priv-house-serv   <=50K    0.993
#                   >50K     0.007
# Prof-specialty    <=50K    0.551
#                   >50K     0.449
# Protective-serv   <=50K    0.675
#                   >50K     0.325
# Sales             <=50K    0.731
#                   >50K     0.269
# Tech-support      <=50K    0.695
#                   >50K     0.305
# ...

# %%
dff_g.columns=["percentage"]
dff_g
# Out:
#                           percentage
# occupation        salary
# Adm-clerical      <=50K        0.865
#                   >50K         0.135
# Armed-Forces      <=50K        0.889
#                   >50K         0.111
# Craft-repair      <=50K        0.773
#                   >50K         0.227
# Exec-managerial   <=50K        0.516
#                   >50K         0.484
# Farming-fishing   <=50K        0.884
#                   >50K         0.116
# Handlers-cleaners <=50K        0.937
#                   >50K         0.063
# Machine-op-inspct <=50K        0.875
#                   >50K         0.124
# Other-service     <=50K        0.958
#                   >50K         0.042
# Priv-house-serv   <=50K        0.993
#                   >50K         0.007
# Prof-specialty    <=50K        0.551
#                   >50K         0.449
# Protective-serv   <=50K        0.675
#                   >50K         0.325
# Sales             <=50K        0.731
# ...

# %%
dff_g.reset_index(inplace=True)

# %%
dff_g
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# ...

# %%
plt.figure(figsize=(12,8))
sns.barplot(x=dff_g.occupation,y=dff_g.percentage,hue=dff_g.salary,palette="husl")
plt.xticks(rotation=90);

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
df2.groupby("salary").occupation.value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(df2.salary,hue=df2.occupation);

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %%
h=df2.groupby("salary").occupation.value_counts(normalize=True)
h
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
# ...

# %%
dff_h=h.to_frame()
dff_h
# Out:
#                           occupation
# salary occupation
# <=50K  Adm-clerical            0.132
#        Craft-repair            0.128
#        Other-service           0.128
#        Sales                   0.108
#        Prof-specialty          0.092
#        Exec-managerial         0.085
#        Machine-op-inspct       0.071
#        Unknown                 0.067
#        Handlers-cleaners       0.052
#        Transport-moving        0.052
#        Farming-fishing         0.036
#        Tech-support            0.026
#        Protective-serv         0.018
#        Priv-house-serv         0.006
#        Armed-Forces            0.000
# >50K   Exec-managerial         0.251
#        Prof-specialty          0.237
#        Sales                   0.125
#        Craft-repair            0.119
#        Adm-clerical            0.065
#        Transport-moving        0.041
#        Tech-support            0.036
#        Machine-op-inspct       0.032
#        Protective-serv         0.027
# ...

# %%
dff_h.columns=["percentage"]

# %%
dff_h.reset_index(inplace=True)
dff_h
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 1   <=50K       Craft-repair       0.128
# 2   <=50K      Other-service       0.128
# 3   <=50K              Sales       0.108
# 4   <=50K     Prof-specialty       0.092
# 5   <=50K    Exec-managerial       0.085
# 6   <=50K  Machine-op-inspct       0.071
# 7   <=50K            Unknown       0.067
# 8   <=50K  Handlers-cleaners       0.052
# 9   <=50K   Transport-moving       0.052
# 10  <=50K    Farming-fishing       0.036
# 11  <=50K       Tech-support       0.026
# 12  <=50K    Protective-serv       0.018
# 13  <=50K    Priv-house-serv       0.006
# 14  <=50K       Armed-Forces       0.000
# 15   >50K    Exec-managerial       0.251
# 16   >50K     Prof-specialty       0.237
# 17   >50K              Sales       0.125
# 18   >50K       Craft-repair       0.119
# 19   >50K       Adm-clerical       0.065
# 20   >50K   Transport-moving       0.041
# 21   >50K       Tech-support       0.036
# ...

# %%
plt.figure(figsize=(15,8))
ax=sns.barplot(x=dff_h.salary,y=dff_h.percentage,hue=dff_h.occupation)
for i in ax.containers:
    ax.bar_label(i,fmt="%.3f");

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** People in managerial and prof-speciality positions earned more than others.

# %% [markdown]
# ## race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df2.race.value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(df2.race,palette="husl")
plt.xticks(rotation=45);

# %% [markdown]
# **Check the count of person in each "salary" levels by races and visualize it with countplot**

# %%
df2.groupby("race").salary.value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(df2.race,hue=df2.salary,palette="spring")
plt.xticks(rotation=45);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %%
j=df2.groupby("race").salary.value_counts(normalize=True)
j
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
df_j=j.unstack(level=0)
df_j
# Out:
# race    Amer-Indian-Eskimo  Asian-Pac-Islander  Black  Other  White
# salary
# <=50K                0.884               0.734  0.876  0.908  0.744
# >50K                 0.116               0.266  0.124  0.092  0.256

# %%
df_j.plot(kind="pie",subplots=True,layout=(2,3),
          title=["Amer-Indian-Eskimo","Asian-Pac-Islander","Black","Other","White"],
          ylabel="salary",
          autopct="%.2f%%",
          legend=False,figsize=(15,10),colors=["#aa7ffa","#bed47d"]);

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
df2.groupby("salary").race.value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(df2.salary,hue=df2.race,palette="gnuplot");

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %%
k=df2.groupby("salary").race.value_counts(normalize=True)
k
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
dff_k=pd.DataFrame(k)
dff_k.columns=["percentage"]
dff_k.reset_index(inplace=True)

# %%
dff_k
# Out:
#   salary                race  percentage
# 0  <=50K               White       0.837
# 1  <=50K               Black       0.111
# 2  <=50K  Asian-Pac-Islander       0.031
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 4  <=50K               Other       0.010
# 5   >50K               White       0.908
# 6   >50K               Black       0.049
# 7   >50K  Asian-Pac-Islander       0.035
# 8   >50K  Amer-Indian-Eskimo       0.005
# 9   >50K               Other       0.003

# %%
plt.figure(figsize=(15,8))
ax= sns.barplot(data=dff_k, x="salary", y="percentage" ,hue="race")
for i in ax.containers:
    ax.bar_label(i,fmt="%.3f");

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** In both cases the proportion of white people is higher.The reason of this white people population is higher than other.

# %% [markdown]
# ## gender

# %% [markdown]
# **Check the count of person in each gender and visualize it with countplot**

# %%
df2.sex.value_counts()
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(df2.sex,palette="autumn")
plt.xlabel("gender");

# %% [markdown]
# **Check the count of person in each "salary" levels by gender and visualize it with countplot**

# %%
df2.groupby("sex").salary.value_counts()
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(df2.sex,hue=df2.salary,palette="autumn")
plt.xlabel("gender");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot**

# %%
m=df2.groupby("sex").salary.value_counts(normalize=True)
m
# Out:
# sex     salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
df_m=m.unstack(level=0)
df_m
# Out:
# sex     Female  Male
# salary
# <=50K    0.890 0.694
# >50K     0.110 0.306

# %%
df_m.plot(kind="pie",subplots=True,layout=(1,2),title=["Female","Male"],
          legend=False,figsize=(12,8),ylabel="salary",autopct="%.2f%%",
          colors=["#7ba3ed","#e8fa61"]);

# %% [markdown]
# **Check the count of person in each gender by "salary" levels and visualize it with countplot**

# %%
df2.groupby("salary").sex.value_counts()
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(df2.salary,hue=df2.sex,palette="mako");

# %% [markdown]
# **Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot**

# %%
n=df2.groupby("salary").sex.value_counts(normalize=True)
n
# Out:
# salary  sex
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: sex, dtype: float64

# %%
df_n=n.unstack(level=0)

# %%
df_n.plot(kind="pie", subplots=True,layout=(1,2),
          legend=False,title=["<=50K",">50K"],figsize=(12,8),
          ylabel="gender",autopct="%.2f%%",
         colors=["#e8fa61","#7ba3ed"]);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** We can say that women in the middle class work because of financel opportunities.Few of the Senior Women chose to work, but in the middle class the situation is different. We can say that middle class women work because of financial means.

# %% [markdown]
# ## native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
df2.native_country.value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
plt.figure(figsize=(15,9))
sns.countplot(x=df2.native_country)
plt.xticks(rotation=90);

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
df2.native_country.replace("?","Unknown",inplace=True)

# %%
df2.native_country.value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# Unknown                         582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
df2.native_country.apply(mapping_native_country).value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %% [raw]
# Desired Output:
#
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
df2["native_country_summary"]=df2.native_country.apply(mapping_native_country)

# %%
df2.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df2["native_country_summary"]
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %%
plt.figure(figsize=(8,6))
sns.countplot(x=df2.native_country_summary,palette="pastel");

# %% [markdown]
# **Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot**

# %%
df2.groupby("native_country_summary").salary.value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df2.native_country_summary,hue=df2.salary,palette="winter");

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %%
p=df2.groupby("native_country_summary").salary.value_counts(normalize=True)
p
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
df_p=p.unstack(level=0)
df_p
# Out:
# native_country_summary  Others    US
# salary
# <=50K                    0.802 0.754
# >50K                     0.198 0.246

# %%
df_p.plot(kind="pie",subplots=True,
          layout=(1,2),title=["Others","US"],
          legend=False,figsize=(15,10),autopct="%.2f%%",
          colors=["#7dbdd4","#e8e382"],ylabel="salary");

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %%
df2.groupby("salary").native_country_summary.value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df2.salary,hue=df2.native_country_summary,palette="viridis");

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %%
r=df2.groupby("salary").native_country_summary.value_counts(normalize=True)
r
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
df_r=r.unstack(level=0)
df_r
# Out:
# salary                  <=50K  >50K
# native_country_summary
# Others                  0.110 0.085
# US                      0.890 0.915

# %%
df_r.plot(kind="pie",subplots=True,layout=(1,2),
          legend=False,title=["<=50K",">50K"],
          ylabel="native_country_summary",
          figsize=(15,9),colors=["#a39da0","#f5cf67"]);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Percentage of US is more higher than the others in the both cases.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
df2.groupby(["salary","sex"]).mean().age
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
x=df2.groupby(["salary","sex"]).mean().age

x
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
df_x=x.to_frame()

# %%
ax=df_x.plot(kind="bar",legend=False,figsize=(10,8))
for i in ax.containers:
    ax.bar_label(i,fmt="%.2f")

# %%
df_x.reset_index(inplace=True)
df_x
# Out:
#   salary     sex    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %%
plt.figure(figsize=(10,8))
ax=sns.barplot(x=df_x.salary,y=df_x.age,hue=df_x.sex)
for i in ax.containers:
    ax.bar_label(i,fmt="%.2f");

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
x=df2[(df2.salary == ">50K") & (df2.native_country_summary == "US")].workclass.value_counts(normalize = True) * 100
x
# Out:
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: workclass, dtype: float64

# %%
plt.figure(figsize=(10,8))
ax=sns.barplot(x=x.index,y=x.values)
plt.xticks(rotation=45)
for i in ax.containers:
    ax.bar_label(i,fmt="%.2f");

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
df.sample()
# Out:
#        age workclass  fnlwgt education  education-num marital-status  \
# 22785   47   Private  343742   HS-grad          9.000      Separated
#
#          occupation relationship   race   sex  capital-gain  capital-loss  \
# 22785  Craft-repair    Unmarried  Black  Male             0             0
#
#        hours-per-week native-country salary
# 22785              40  United-States  <=50K

# %%
y=df2[(df2.salary == ">50K") & (df2.native_country_summary == "US") & (df2.workclass == "Private")].occupation.value_counts(normalize = True) * 100
y
# Out:
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
plt.figure(figsize=(10,8))
ax=sns.barplot(x=y.index,y=y.values)
plt.xticks(rotation=90)
for i in ax.containers:
    ax.bar_label(i,fmt="%.2f");

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
z=df2[(df2.salary == ">50K") & (df2.race == "Asian-Pac-Islander")].education.value_counts(normalize = True) * 100
z
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
plt.figure(figsize=(10,8))
ax=sns.barplot(x=z.index,y=z.values)
plt.xticks(rotation=90)
for i in ax.containers:
    ax.bar_label(i,fmt="%.2f");

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
t=df2[(df2.salary == ">50K") & (df2.race == "Asian-Pac-Islander") & (df2.education == "Bachelors")].occupation.value_counts(normalize = True) * 100
t
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
plt.figure(figsize=(10,8))
ax=sns.barplot(x=t.index,y=t.values)
plt.xticks(rotation=90)
for i in ax.containers:
    ax.bar_label(i,fmt="%.2f");

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
df_g=df2.groupby(["sex","education_summary","marital_status_summary","native_country_summary"]).hours_per_week.mean().to_frame()
df_g
# Out:
#                                                                          hours_per_week
# sex    education_summary  marital_status_summary native_country_summary
# Female high_level_grade   married                Others                          39.127
#                                                  US                              38.478
#                           unmarried              Others                          40.155
#                                                  US                              40.784
#        low_level_grade    married                Others                          36.628
#                                                  US                              37.256
#                           unmarried              Others                          35.651
#                                                  US                              30.556
#        medium_level_grade married                Others                          36.574
# ...

# %%
df2.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df2.groupby(["marital_status_summary","native_country_summary","sex"]).hours_per_week.mean()
# Out:
# marital_status_summary  native_country_summary  sex
# married                 Others                  Female   37.265
#                                                 Male     43.127
#                         US                      Female   36.628
#                                                 Male     44.196
# unmarried               Others                  Female   37.098
#                                                 Male     39.566
#                         US                      Female   36.276
#                                                 Male     39.737
# Name: hours_per_week, dtype: float64

# %%
g=sns.catplot(x="education_summary",y="hours_per_week",data=df2,hue="sex",
               kind="bar",col="marital_status_summary",ci=None,row="native_country_summary",palette="autumn")
g.fig.set_size_inches(16,8)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle("Working Hours Per Week by Gender for Education ,Workclass ,Marital Status")
for ax in g.axes.ravel():

    
    for i in ax.containers:
        ax.bar_label(i,fmt="%.2f");

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            27473 non-null  object
#  8   race                    32537 non-null  object
#  9   sex                     32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
# ...

# %%
df2_drop=df2.drop(columns=["education","education_num","relationship","marital_status","native_country"])

# %%
df2_drop
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %%
df2_drop.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
df2_drop.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df2_drop.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df2_drop.workclass.value_counts().loc[["Unknown","Never-worked"]]
# Out:
# Unknown         1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
df2_drop["workclass"]=df2_drop.workclass.replace("Unknown",np.nan)

# %%
df2_drop["occupation"]=df2_drop.occupation.replace("Unknown",np.nan)

# %%
df2_drop.isnull().sum()
# Out:
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# sex                          0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %% [raw]
# Desired Output:
#
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# gender                       0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %%
dff=df2_drop.dropna()

# %%
dff.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   sex                     30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### Boxplot and Histplot for all numeric features
#
# **Plot boxplots for each numeric features at the same figure as subplots**

# %%
dff.select_dtypes("number")
# Out:
#        age  fnlwgt  capital_gain  capital_loss  hours_per_week
# 0       39   77516          2174             0              40
# 1       50   83311             0             0              13
# 2       38  215646             0             0              40
# 3       53  234721             0             0              40
# 4       28  338409             0             0              40
# ...    ...     ...           ...           ...             ...
# 32556   27  257302             0             0              38
# 32557   40  154374             0             0              40
# 32558   58  151910             0             0              40
# 32559   22  201490             0             0              20
# 32560   52  287927         15024             0              40
#
# [30694 rows x 5 columns]

# %%
dff.select_dtypes("number").columns
# Out:
# Index(['age', 'fnlwgt', 'capital_gain', 'capital_loss', 'hours_per_week'], dtype='object')

# %%
plt.figure(figsize=(10,8))
plt.boxplot(dff.select_dtypes('number'), 
            labels=dff.select_dtypes('number').columns);

# %%
plt.figure(figsize=(15,10))
index=0
for i in dff.select_dtypes('number').columns:
    index += 1
    plt.subplot(2,3,index)
    sns.boxplot(x=i, 
                data=dff)

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %%
plt.figure(figsize=(20,15))
index=0
for i in dff.select_dtypes("number").columns:
    index+=1
    plt.subplot(5,2,index)
    sns.boxplot(x=i,data=dff)
    index+=1
    plt.subplot(5,2,index)
    sns.histplot(x=i,data=dff)
plt.tight_layout();

# %% [markdown]
# **Check the statistical values for all numeric features**

# %%
dff.select_dtypes("number").describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            30694.000     38.448     13.115    17.000     28.000
# fnlwgt         30694.000 189848.229 105465.126 13769.000 117828.500
# capital_gain   30694.000   1106.902   7500.730     0.000      0.000
# capital_loss   30694.000     88.980    405.808     0.000      0.000
# hours_per_week 30694.000     40.953     11.984     1.000     40.000
#
#                       50%        75%         max
# age                37.000     47.000      90.000
# fnlwgt         178513.500 237293.750 1484705.000
# capital_gain        0.000      0.000   99999.000
# capital_loss        0.000      0.000    4356.000
# hours_per_week     40.000     45.000      99.000

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
plt.figure(figsize=(10,9))
plt.subplot(1,2,1)
sns.boxplot(y="age",data=dff)
plt.ylabel("")
plt.subplot(1,2,2)
sns.histplot(x="age",data=dff);

# %%
q1=dff.age.quantile(0.25)

q3=dff.age.quantile(0.75)

IQR=q3 - q1
lower_lim=q1-1.5*IQR

upper_lim=q3+1.5*IQR

# %%
q1,q3,IQR
# Out:
# (28.0, 47.0, 19.0)

# %%
lower_lim, upper_lim
# Out:
# (-0.5, 75.5)

# %%
dff[dff.age > upper_lim].age.value_counts()
# Out:
# 90    35
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
dff[dff.age > upper_lim].sort_values(by="age",ascending=False)
# Out:
#        age         workclass  fnlwgt       occupation                race  \
# 8806    90           Private   87372   Prof-specialty               White
# 14159   90         Local-gov  187749     Adm-clerical  Asian-Pac-Islander
# 28463   90       Federal-gov  195433     Craft-repair               White
# 12975   90           Private  250832  Exec-managerial               White
# 11996   90           Private   40388  Exec-managerial               White
# ...    ...               ...     ...              ...                 ...
# 15102   76         Local-gov  169133     Adm-clerical               White
# 19085   76           Private  125784  Exec-managerial               White
# 23515   76           Private  142535     Adm-clerical               White
# 8240    76  Self-emp-not-inc  225964            Sales               White
# 23354   76           Private  199949     Adm-clerical               White
#
#           sex  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %% [markdown]
# ### hours_per_week

# %%
plt.figure(figsize=(15,9))
plt.subplot(1,2,1)
sns.boxplot(y="hours_per_week",data=dff)
plt.ylabel("")
plt.subplot(1,2,2)
sns.histplot(x="hours_per_week",data=dff,bins=10);

# %%
q1=dff.hours_per_week.quantile(0.25)

q3=dff.hours_per_week.quantile(0.75)

IQR=q3 - q1
lower_lim=q1-1.5*IQR

upper_lim=q3+1.5*IQR

# %%
q1,q3,IQR
# Out:
# (40.0, 45.0, 5.0)

# %%
lower_lim, upper_lim
# Out:
# (32.5, 52.5)

# %%
dff[dff.hours_per_week > upper_lim].hours_per_week.value_counts().sort_index(ascending=False)
# Out:
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
dff[dff.hours_per_week > upper_lim].sort_values(by="hours_per_week",ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation   race     sex  \
# 25986   44         Local-gov  212665   Protective-serv  Black    Male
# 19529   38           Private   66326  Transport-moving  White    Male
# 8796    39           Private   70995  Transport-moving  White    Male
# 15534   29           Private  167716     Other-service  White  Female
# 22313   26  Self-emp-not-inc  258306   Farming-fishing  White    Male
# ...    ...               ...     ...               ...    ...     ...
# 1138    27           Private  138705      Craft-repair  White    Male
# 23244   58           Private  248739   Farming-fishing  White    Male
# 28858   62           Private  123411  Transport-moving  White    Male
# 18417   24           Private  117167     Other-service  White  Female
# 31622   61  Self-emp-not-inc  268831             Sales  White    Male
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %%
dff[dff.hours_per_week < lower_lim].hours_per_week.value_counts().sort_index()
# Out:
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
dff[dff.hours_per_week<lower_lim].groupby("salary").describe().hours_per_week
# Out:
#           count   mean   std   min    25%    50%    75%    max
# salary
# <=50K  4372.000 21.548 7.343 1.000 16.000 20.000 30.000 32.000
# >50K    322.000 22.028 7.813 1.000 18.000 24.000 30.000 32.000

# %%
dff[dff.hours_per_week<lower_lim].groupby("salary").describe().age
# Out:
#           count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  4372.000 34.052 17.730 17.000 20.000 26.000 45.000 90.000
# >50K    322.000 49.484 13.894 22.000 39.000 48.000 60.000 90.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/swYNtdM/102.png)

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
dff_age=dff[(dff.age<17) | (dff.age>80)].sort_values(by="age",ascending=False)
dff_age
# Out:
#        age     workclass  fnlwgt       occupation   race     sex  \
# 222     90       Private   51744    Other-service  Black    Male
# 18832   90       Private  115306  Exec-managerial  White  Female
# 10545   90       Private  175491     Craft-repair  White    Male
# 11512   90       Private   87285    Other-service  White  Female
# 11996   90       Private   40388  Exec-managerial  White    Male
# ...    ...           ...     ...              ...    ...     ...
# 19045   81     State-gov  132204    Other-service  White  Female
# 6748    81       Private  122651            Sales  White    Male
# 2906    81       Private  114670  Priv-house-serv  Black  Female
# 21501   81       Private  177408  Exec-managerial  White    Male
# 19495   81  Self-emp-inc  247232  Exec-managerial  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 222               0          2206              40  <=50K  medium_level_grade
# ...

# %%
dff_age.shape
# Out:
# (76, 13)

# %%
dff_age.index
# Out:
# Int64Index([  222, 18832, 10545, 11512, 11996, 12975, 14159, 15892, 18277,
#             18413, 18725, 19212,  8973, 19489, 19747, 20610, 22220, 24043,
#             28463, 31030, 32277, 32367, 10210, 15356,  5370,  4070,  1040,
#              6232,  1935,  2303,  5272,  6624,  2891,  5406,  8806,  1168,
#             22895, 21835, 24027, 20463,  8381, 32459, 26731, 27795,  9471,
#              6214, 14711, 11238,  7720, 15662,  7481, 24395, 23459, 19172,
#             16302, 14756,  8431, 20421, 22481, 31855, 13696, 24280,  4834,
#             29594, 28948, 12830,   918, 13295, 24560,  3537, 13928, 19045,
#              6748,  2906, 21501, 19495],
#            dtype='int64')

# %%
dff_drop_age=dff.drop(index=dff_age.index)

# %%
dff_drop_age
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %%
dff_hours=dff_drop_age[(dff_drop_age.hours_per_week<7) | (dff_drop_age.hours_per_week>70)].sort_values(by="hours_per_week",ascending=False)
dff_hours
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 22216   45           Private   54260      Craft-repair               White
# 5432    44           Private   83508    Prof-specialty               White
# 19053   27           Private   40295  Transport-moving               White
# 19141   59           Private  106748     Other-service               White
# 19399   39      Self-emp-inc  163057      Craft-repair               White
# ...    ...               ...     ...               ...                 ...
# 20909   77  Self-emp-not-inc   71676      Adm-clerical               White
# 25078   74           Private  260669     Other-service               White
# 19750   23           Private   72887      Craft-repair  Asian-Pac-Islander
# 189     58         State-gov  109567    Prof-specialty               White
# 24284   57  Self-emp-not-inc   56480   Exec-managerial               White
#
#           sex  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %%
dff_hours.shape
# Out:
# (621, 13)

# %%
dff_hours.index
# Out:
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
dff_drop_hours=dff_drop_age.drop(index=dff_hours.index)
dff_drop_hours
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %%
dff_60=dff_drop_hours[(dff_drop_hours.age > 60) & (dff_drop_hours.hours_per_week > 60)]
dff_60
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 1541    62           Private  162245    Prof-specialty               White
# 2154    75           Private  101887   Priv-house-serv               White
# 2184    63      Self-emp-inc   54052             Sales               White
# 2665    70           Private   94692             Sales               White
# 3101    65      Self-emp-inc   81413   Farming-fishing               White
# 5417    67           Private  197816             Sales               White
# 6826    68           Private  284763  Transport-moving               White
# 8066    61  Self-emp-not-inc  133969             Sales  Asian-Pac-Islander
# 9646    62  Self-emp-not-inc   26911     Other-service               White
# 12624   63      Self-emp-inc  110890    Prof-specialty               White
# 16634   62  Self-emp-not-inc  115176   Farming-fishing               White
# ...

# %%
dff_60.shape
# Out:
# (23, 13)

# %%
dff_60.index
# Out:
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
dff_last=dff_drop_hours.drop(index=dff_60.index)
dff_last
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 0       39         State-gov   77516       Adm-clerical  White    Male
# 1       50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2       38           Private  215646  Handlers-cleaners  White    Male
# 3       53           Private  234721  Handlers-cleaners  Black    Male
# 4       28           Private  338409     Prof-specialty  Black  Female
# ...    ...               ...     ...                ...    ...     ...
# 32556   27           Private  257302       Tech-support  White  Female
# 32557   40           Private  154374  Machine-op-inspct  White    Male
# 32558   58           Private  151910       Adm-clerical  White  Female
# 32559   22           Private  201490       Adm-clerical  White    Male
# 32560   52      Self-emp-inc  287927    Exec-managerial  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %%
dff_last.shape
# Out:
# (29974, 13)

# %%
dff_last.head()
# Out:
#    age         workclass  fnlwgt         occupation   race     sex  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
#
#    capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 0          2174             0              40  <=50K    high_level_grade
# 1             0             0              13  <=50K    high_level_grade
# 2             0             0              40  <=50K  medium_level_grade
# 3             0             0              40  <=50K     low_level_grade
# 4             0             0              40  <=50K    high_level_grade
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US
# ...

# %%
dff_last.reset_index(drop=True,inplace=True)

# %%
dff_last.head()
# Out:
#    age         workclass  fnlwgt         occupation   race     sex  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
#
#    capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 0          2174             0              40  <=50K    high_level_grade
# 1             0             0              13  <=50K    high_level_grade
# 2             0             0              40  <=50K  medium_level_grade
# 3             0             0              40  <=50K     low_level_grade
# 4             0             0              40  <=50K    high_level_grade
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %%
dff_last.salary.map({"<=50K":0,">50K":1})
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29969    0
# 29970    1
# 29971    0
# 29972    0
# 29973    1
# Name: salary, Length: 29974, dtype: int64

# %%
dff_last.salary=dff_last.salary.map({"<=50K":0,">50K":1})

# %%
dff_last.head(10)
# Out:
#    age         workclass  fnlwgt         occupation   race     sex  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
# 5   37           Private  284582    Exec-managerial  White  Female
# 6   49           Private  160187      Other-service  Black  Female
# 7   52  Self-emp-not-inc  209642    Exec-managerial  White    Male
# 8   31           Private   45781     Prof-specialty  White  Female
# 9   42           Private  159449    Exec-managerial  White    Male
#
#    capital_gain  capital_loss  hours_per_week  salary   education_summary  \
# 0          2174             0              40       0    high_level_grade
# 1             0             0              13       0    high_level_grade
# ...

# %%
dff_last.salary.value_counts()
# Out:
# 0    22524
# 1     7450
# Name: salary, dtype: int64

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
dff_dummies=pd.get_dummies(dff_last,drop_first=True)

# %%
dff_dummies
# Out:
#        age  fnlwgt  capital_gain  capital_loss  hours_per_week  salary  \
# 0       39   77516          2174             0              40       0
# 1       50   83311             0             0              13       0
# 2       38  215646             0             0              40       0
# 3       53  234721             0             0              40       0
# 4       28  338409             0             0              40       0
# ...    ...     ...           ...           ...             ...     ...
# 29969   27  257302             0             0              38       0
# 29970   40  154374             0             0              40       1
# 29971   58  151910             0             0              40       0
# 29972   22  201490             0             0              20       0
# 29973   52  287927         15024             0              40       1
#
#        workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# ...

# %%
dff_last.shape
# Out:
# (29974, 13)

# %%
dff_dummies.shape
# Out:
# (29974, 34)

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
dff_dummies.corr()
# Out:
#                                         age  fnlwgt  capital_gain  \
# age                                   1.000  -0.074         0.082
# fnlwgt                               -0.074   1.000        -0.002
# capital_gain                          0.082  -0.002         1.000
# capital_loss                          0.059  -0.011        -0.032
# hours_per_week                        0.119  -0.019         0.086
# salary                                0.253  -0.010         0.222
# workclass_Local-gov                   0.070  -0.004        -0.010
# workclass_Private                    -0.211   0.045        -0.045
# workclass_Self-emp-inc                0.111  -0.025         0.093
# workclass_Self-emp-not-inc            0.146  -0.037         0.033
# workclass_State-gov                   0.020  -0.012        -0.013
# workclass_Without-pay                 0.016  -0.003        -0.002
# occupation_Armed-Forces              -0.011   0.004        -0.003
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data=dff_dummies.corr(),annot=True,cmap="PiYG");

# %%
dff_dummies_salary=dff_dummies.corr()[["salary"]].drop("salary").sort_values(by="salary",ascending=False)
dff_dummies_salary
# Out:
#                                       salary
# age                                    0.253
# hours_per_week                         0.247
# capital_gain                           0.222
# sex_Male                               0.216
# occupation_Exec-managerial             0.215
# occupation_Prof-specialty              0.185
# capital_loss                           0.152
# workclass_Self-emp-inc                 0.138
# race_White                             0.086
# native_country_summary_US              0.035
# workclass_Self-emp-not-inc             0.030
# workclass_Local-gov                    0.029
# occupation_Protective-serv             0.026
# occupation_Tech-support                0.023
# occupation_Sales                       0.015
# race_Asian-Pac-Islander                0.012
# workclass_State-gov                    0.011
# occupation_Armed-Forces               -0.006
# fnlwgt                                -0.010
# workclass_Without-pay                 -0.012
# ...

# %%
plt.figure(figsize=(3,12))
sns.heatmap(data=dff_dummies_salary,annot=True,cmap="PiYG");

# %%
dff_dummies_salary.sort_values(by="salary").plot.barh(legend=False,figsize=(5,15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
