# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
gas=pd.read_csv("gas_prices.csv")
gas.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
plt.figure(figsize=(8,5))
plt.plot(gas.Year,gas.USA, "r.-",label="United States")
plt.plot(gas.Year,gas.Canada, "b.-",label="Canada")
plt.plot(gas.Year,gas["South Korea"], label="South Korea")
plt.ylabel("Dollars/Gallon")
plt.title("USA vs Canada Gas Prices")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(gas.Year,gas.USA, "r.-",label="United States")
plt.plot(gas.Year,gas.Canada, "b.-",label="Canada")
plt.plot(gas.Year,gas["South Korea"], label="South Korea")
plt.ylabel("Dollars/Gallon")
plt.title("USA vs Canada Gas Prices")
plt.xticks(gas.Year)
plt.legend()
plt.show()

# %%
print(gas.Year) # maybe we should do every 3 years
# Out:
# 0     1990
# 1     1991
# 2     1992
# 3     1993
# 4     1994
# 5     1995
# 6     1996
# 7     1997
# 8     1998
# 9     1999
# 10    2000
# 11    2001
# 12    2002
# 13    2003
# 14    2004
# 15    2005
# 16    2006
# 17    2007
# 18    2008
# Name: Year, dtype: int64

# %%
print(gas.Year[::3]) # we get every third year which will probably better when we graph it down
# Out:
# 0     1990
# 3     1993
# 6     1996
# 9     1999
# 12    2002
# 15    2005
# 18    2008
# Name: Year, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.plot(gas.Year,gas.USA, "r.-",label="United States")
plt.plot(gas.Year,gas.Canada, "b.-",label="Canada")
plt.plot(gas.Year,gas["South Korea"],"g.-", label="South Korea")
plt.plot(gas.Year,gas.Australia, "y.-",label="Australia")
plt.ylabel("Dollars/Gallon")
plt.title("USA vs Canada Gas Prices")
plt.xticks(gas.Year[::3]) # that looks pretty good
plt.legend()
plt.show()

# %%
for country in gas :
    if country !="Year":
        plt.plot(gas.Year,gas[country],marker=".",label=country)
        plt.xticks(gas.Year[::3])
        plt.legend(loc="upper left")

# %%
countries_to_look_at=["Australia","USA","Canada","South Korea"]
for country in gas :
    if country in countries_to_look_at:
        plt.plot(gas.Year,gas[country],marker=".",label=country)
        plt.xticks(gas.Year[::3])
        plt.legend(loc="upper left")

# %%
plt.figure(figsize=(8,5))
plt.plot(gas.Year,gas.USA, "r.-",label="United States")
plt.plot(gas.Year,gas.Canada, "b.-",label="Canada")
plt.plot(gas.Year,gas["South Korea"],"g.-", label="South Korea")
plt.plot(gas.Year,gas.Australia, "y.-",label="Australia")
plt.ylabel("Dollars/Gallon")
plt.title("Countries Gas Prices",fontdict={"fontweight":"bold","fontsize":18})
plt.xticks(gas.Year[::3]) # that looks pretty good
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(gas.Year,gas.USA, "r.-",label="United States")
plt.plot(gas.Year,gas.Canada, "b.-",label="Canada")
plt.plot(gas.Year,gas["South Korea"],"g.-", label="South Korea")
plt.plot(gas.Year,gas.Australia, "y.-",label="Australia")
plt.ylabel("Dollars/Gallon")
plt.title("Countries Gas Prices",fontdict={"fontweight":"bold","fontsize":18})
plt.xticks(gas.Year[::3].tolist()+ [2011]) # I don't have a value in 2011, but I want to add it to the table in that year.
# We made a list of data with tolist for sum operation
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(gas.Year,gas.USA, "r.-",label="United States")
plt.plot(gas.Year,gas.Canada, "b.-",label="Canada")
plt.plot(gas.Year,gas["South Korea"],"g.-", label="South Korea")
plt.plot(gas.Year,gas.Australia, "y.-",label="Australia")
plt.ylabel("Dollars/Gallon")
plt.title("Countries Gas Prices",fontdict={"fontweight":"bold","fontsize":18})
plt.xticks(gas.Year[::3].tolist()+ [2011]) # I don't have a value in 2011, but I want to add it to the table in that year.
# We made a list of data with tolist for sum operation
plt.legend()
plt.savefig("Gas_Prices.png",dpi=300) # when we are the saving if change the dpiyou will get a higher resolution image 
plt.show()
